# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("C:\\Users\\lenovo\\OneDrive\\Desktop\\cleaned_travel_data.csv")

# %%
df
# Out:
#                                           package_name  actual_price  \
# 0    Bestselling Rishikesh Mussoorie Tour Package F...         12545
# 1    Best Hong Kong Macau Tour Packages For An Impe...         43157
# 2                Coorg Package For 2 Nights And 3 Days         17802
# 3    Refreshing Maldives Family Tour Packages From ...         80000
# 4    Best 4N 5D Andaman Sightseeing Tour Package Fo...         36484
# ..                                                 ...           ...
# 466          Sizzling Pattaya Sightseeing Tour Package         37362
# 467                     Adventurous Assam Tour Package         15730
# 468  New Zealand Queenstown, Rotorua & Franz Josef ...        150081
# 469   Ecstatic Cambodia Vietnam Family Holiday Package         61111
# 470                 Gleeful Rann Of Kutch Tour Package         22087
#
#      trip_price                                    visiting_places  \
# 0         11549                     Rishikesh (1D),Mussoorie (2D),
# ...

# %%
df.describe()
# Out:
#         actual_price     trip_price      discount        days  \
# count     471.000000     471.000000    471.000000  471.000000
# mean    40190.114650   36355.749469   3834.365180    5.479830
# std     37131.740963   34063.137989   3875.360378    2.482945
# min      3360.000000    2800.000000    122.000000    2.000000
# 25%     15979.500000   14499.500000   1489.000000    4.000000
# 50%     27777.000000   25000.000000   2788.000000    5.000000
# 75%     49115.000000   44649.000000   4716.500000    7.000000
# max    274725.000000  250000.000000  45000.000000   20.000000
#
#        no.of_visiting_cities
# count             471.000000
# mean                2.188960
# std                 1.450006
# min                 1.000000
# 25%                 1.000000
# 50%                 2.000000
# 75%                 3.000000
# max                 8.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 471 entries, 0 to 470
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   package_name           471 non-null    object
#  1   actual_price           471 non-null    int64
#  2   trip_price             471 non-null    int64
#  3   visiting_places        471 non-null    object
#  4   hotel_ratings          471 non-null    object
#  5   city_name              471 non-null    object
#  6   discount               471 non-null    int64
#  7   days                   471 non-null    int64
#  8   no.of_visiting_cities  471 non-null    int64
# dtypes: int64(5), object(4)
# memory usage: 33.2+ KB

# %%
df.groupby('city_name')['trip_price'].mean().sort_values(ascending=True)
# Out:
# city_name
# sariska         4500.0
# Dwarka          6000.0
# Pachmarhi       6000.0
# Candolim        7319.0
# Agra            7750.0
#                 ...
# Amman         103999.5
# Las Vegas     160000.0
# Calodyne      161288.0
# Orlando       169000.0
# New York      250000.0
# Name: trip_price, Length: 123, dtype: float64

# %% [markdown]
# - OBSERVATION:
# - Trip prices for the above mentioned cities on an average are sorted and can be travelled according to the budget.

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 4))

# Plot for the lowest average trip prices (head)
df.groupby('city_name')['trip_price'].mean().sort_values(ascending=True).head().plot(
    kind='bar', color='skyblue', ax=axes[0])
axes[0].set_title('Lowest Budget cities')
axes[0].set_xlabel('City Name')
axes[0].set_ylabel('Average Trip Price')

# Plot for the highest average trip prices (tail)
df.groupby('city_name')['trip_price'].mean().sort_values(ascending=True).tail().plot(
    kind='bar', color='skyblue', ax=axes[1])
axes[1].set_title('Highest Budget cities')
axes[1].set_xlabel('City Name')
axes[1].set_ylabel('Average Trip Price')

# Adjust the layout for better spacing
plt.tight_layout()

# Display the plots
plt.show()

# %%
# least costed cities to travel
plt.figure(figsize=(5,3))
df.groupby('city_name')['trip_price'].mean().sort_values(ascending=True).head().plot(kind='bar', color='skyblue')
plt.title('Average Trip Price by City')
plt.xlabel('City Name')
plt.ylabel('Average Trip Price')
plt.show()

# %%
# high budget cities
plt.figure(figsize=(5,3))
df.groupby('city_name')['trip_price'].mean().sort_values(ascending=True).tail().plot(kind='bar', color='skyblue')
plt.title('Average Trip Price by City')
plt.ylabel('Average Trip Price')
plt.xlabel('City Name')
plt.show()

# %%
df[df.discount>20000]
# Out:
#                                           package_name  actual_price  \
# 3    Refreshing Maldives Family Tour Packages From ...         80000
# 411                            Exotic USA Tour Package        274725
#
#      trip_price                                    visiting_places  \
# 3         35000                                     Maldives (5D),
# 411      250000  New York (2D),Washington DC (1D),Niagara Falls...
#
#              hotel_ratings  city_name  discount  days  no.of_visiting_cities
# 3    3 Star,4 Star,5 Star,  Maldives      45000     5                      1
# 411                3 Star,  New York      24725    14                      6

# %% [markdown]
# - OBSERVATION:
# - Maldives and New York have highest discounts where these are the best tourist places to visit for a vacation.

# %%
df['hotel_ratings']=df['hotel_ratings'].replace('â\x82¹ 62,000/-', np.nan)

# %%
df['hotel_ratings']=df['hotel_ratings'].replace('â\x82¹ 45,999/-â\x82¹ 49,493/-', np.nan)

# %%
df['hotel_ratings']=df['hotel_ratings'].str.replace('Hotels Included', '', regex=False)

# %%
df['hotel_ratings'].unique()
# Out:
# array(['3 Star,', '3 Star,2 Star,4 Star,', '3 Star,4 Star,5 Star,',
#        '3 Star,4 Star,', '2 Star,3 Star,4 Star,',
#        '2 Star,3 Star,4 Star,5 Star,', '4 Star,', '2 Star,4 Star,',
#        '2 Star,3 Star,', '2 Star,3 Star,5 Star,', '4 Star,5 Star,',
#        '5 Star, ', nan, '5 Star,', '2 Star,', '4 Star,4 Star,',
#        '4 Star,4 Star,5 Star,', '3 Star,3 Star,4 Star,',
#        '4 Star,3 Star,5 Star,', '3 Star,5 Star,', '3,  4,  5 Star, ',
#        '3 Star,3 Star,5 Star,', '3 Star,3 Star,4 Star,5 Star,',
#        '3 Star,3 Star,'], dtype=object)

# %%
df.columns
# Out:
# Index(['package_name', 'actual_price', 'trip_price', 'visiting_places',
#        'hotel_ratings', 'city_name', 'discount', 'days',
#        'no.of_visiting_cities'],
#       dtype='object')

# %%
df.hotel_ratings.fillna('none',inplace=True)

# %%
df.hotel_ratings.unique()
# Out:
# array(['3 Star,', '3 Star,2 Star,4 Star,', '3 Star,4 Star,5 Star,',
#        '3 Star,4 Star,', '2 Star,3 Star,4 Star,',
#        '2 Star,3 Star,4 Star,5 Star,', '4 Star,', '2 Star,4 Star,',
#        '2 Star,3 Star,', '2 Star,3 Star,5 Star,', '4 Star,5 Star,',
#        '5 Star, ', 'none', '5 Star,', '2 Star,', '4 Star,4 Star,',
#        '4 Star,4 Star,5 Star,', '3 Star,3 Star,4 Star,',
#        '4 Star,3 Star,5 Star,', '3 Star,5 Star,', '3,  4,  5 Star, ',
#        '3 Star,3 Star,5 Star,', '3 Star,3 Star,4 Star,5 Star,',
#        '3 Star,3 Star,'], dtype=object)

# %%
high_rating=df[df['hotel_ratings'].str.contains('5 Star')]

# %%
high_rating
# Out:
#                                           package_name  actual_price  \
# 3    Refreshing Maldives Family Tour Packages From ...         80000
# 6    Most Affordable 1 Night 2 Days Uttarakhand Tou...          3360
# 9    Top 4 Nights 5 Days Best-Selling Sikkim Gangto...         22956
# 10   Best Selling Kerala Houseboat & Jungle Safari ...         21993
# 11   Top Greece Tour Packages For An Enthralling Ex...         74974
# ..                                                 ...           ...
# 450         Thrilling Dubai Desert Safari Tour Package         37500
# 461                        Kerala is a Land of Wonders         22988
# 464  Exciting Kanyakumari-Kovalam Family Tour Package          13068
# 468  New Zealand Queenstown, Rotorua & Franz Josef ...        150081
# 469   Ecstatic Cambodia Vietnam Family Holiday Package         61111
#
#      trip_price                                    visiting_places  \
# 3         35000                                     Maldives (5D),
# ...

# %%
#sns.lineplot(x='hotel_ratings', y='trip_price', data=high_rating, label='trip_Price', color='pink')
ratings_trip_price=high_rating.groupby('hotel_ratings')['trip_price'].mean().reset_index()
ratings_trip_price
# Out:
#                    hotel_ratings    trip_price
# 0   2 Star,3 Star,4 Star,5 Star,  42692.285714
# 1          2 Star,3 Star,5 Star,  38497.000000
# 2   3 Star,3 Star,4 Star,5 Star,   6999.000000
# 3          3 Star,3 Star,5 Star,  32262.000000
# 4          3 Star,4 Star,5 Star,  34622.393443
# 5                 3 Star,5 Star,  34750.000000
# 6               3,  4,  5 Star,   21350.000000
# 7          4 Star,3 Star,5 Star,  21600.000000
# 8          4 Star,4 Star,5 Star,  34317.666667
# 9                 4 Star,5 Star,  39849.333333
# 10                       5 Star,  46251.904762
# 11                      5 Star,   28500.000000

# %%
sns.lineplot(x='hotel_ratings', y='trip_price', data=ratings_trip_price, marker='o', color='blue')
plt.title('Average Trip Price by Hotel Ratings', fontsize=16)
plt.xlabel('Hotel Ratings', fontsize=12)
plt.ylabel('Average Trip Price', fontsize=12)
plt.xticks(rotation=90) 

# Show plot
plt.show()

# %%
plt.plot(high_rating.index, dff1['actual_price'], marker='o', label='Actual Price', color='green')
plt.plot(high_rating.index, dff1['trip_price'], marker='o', label='Trip Price', color='red')
plt.title('Average Actual Price and Trip Price by City in Medium Budget')
plt.ylabel('Average Price')
plt.xlabel('City Name')
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.show()

# %%
high_rating.groupby('city_name')['trip_price'].mean().sort_values(ascending=True).sample(10)
# Out:
# city_name
# Siem Reap     22998.000000
# Cochin        12899.000000
# Bangkok       19874.000000
# Rome          20740.000000
# Singapore     45249.500000
# Jaipur        40049.500000
# Phuket        22483.333333
# Lucerne       17590.000000
# Munnar        20337.250000
# Goa           44899.500000
# Name: trip_price, dtype: float64

# %% [markdown]
# - OBSERVATION:
# - These are top 10 cities where we get 5 star hotels in reasonable price.

# %%
sns.boxplot(data=df,x='trip_price')
# Out:
# <Axes: xlabel='trip_price'>

# %% [markdown]
# - OBSERVATION:
# - We have some cities where the trip price is very large and affecting the average trips cost and can be identified as outliers

# %%
highest_discount=df[df.discount>=15000]

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 6))  # 1 row, 2 columns

# Violin plot for the first DataFrame (df)
sns.violinplot(x='discount', data=df, ax=axes[0])
axes[0].set_title('Violin Plot for discount')

# Violin plot for the second DataFrame (highest_discount)
sns.violinplot(x='discount', data=highest_discount, ax=axes[1])
axes[1].set_title('Violin Plot for highest_discount')

# Adjust layout for better spacing
plt.tight_layout()

# Show the plots
plt.show()

# %% [markdown]
# - Here we can't find the best hotels where we got more discount and that is affecting the hotel_ratings.

# %%
df.groupby('city_name')[['days','no.of_visiting_cities']].max().sort_values(by='no.of_visiting_cities',ascending=False)
# Out:
#            days  no.of_visiting_cities
# city_name
# Auckland     20                      8
# Kochi         9                      8
# Jaipur       11                      7
# Rome         14                      7
# Srinagar     10                      7
# ...         ...                    ...
# Guwahati      3                      1
# Goa           6                      1
# Pelling       3                      1
# Dwarka        3                      1
# sariska       3                      1
#
# [123 rows x 2 columns]

# %%
sns.displot(df,x='discount',y='days',kind='kde')

# %% [markdown]
# - OBSERVATION:
# - No.of days affect the discount.

# %%
def ratings():
    two_star = 0
    three_star = 0
    four_star = 0
    five_star = 0
    
    for rating in df['hotel_ratings']:
        individual_ratings = [r.strip() for r in rating.split(',')]
        
        if '2 Star' in individual_ratings:
            two_star += 1
        if '3 Star' in individual_ratings:
            three_star += 1
        if '4 Star' in individual_ratings:
            four_star += 1
        if '5 Star' in individual_ratings:
            five_star += 1

    return two_star, three_star, four_star, five_star

two_star, three_star, four_star, five_star = ratings()

print(f"2 Star: {two_star}, 3 Star: {three_star}, 4 Star: {four_star}, 5 Star: {five_star}")
# Out:
# 2 Star: 54, 3 Star: 331, 4 Star: 210, 5 Star: 112

# %%
df_exploded = df.assign(hotel_ratings=df['hotel_ratings'].str.split(',')).explode('hotel_ratings')
df_exploded['hotel_ratings'] = df_exploded['hotel_ratings'].str.strip()
sns.countplot(x='hotel_ratings', data=df_exploded, order=df_exploded['hotel_ratings'].value_counts().index)
plt.title('Count of Each Hotel Rating')
plt.xlabel('Hotel Ratings')
plt.ylabel('Count')
plt.xticks(rotation=45) 
plt.show()

# %% [markdown]
# - OBSERVATION
# - We have the count of hotel_ratings from the dataset

# %%
sns.histplot(df['days'], bins=10, kde=True)
plt.title('Distribution of Trip Days')
plt.xlabel('Number of Days')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# - OBSERVATION:
# - most of the trips are lasting around 4 to 5 days

# %%
days_counts
# Out:
# no.of_visiting_cities
# 1    211
# 2    109
# 3     69
# 4     37
# 5     30
# 6     10
# 7      3
# 8      2
# Name: count, dtype: int64

# %%
days_counts = df['no.of_visiting_cities'].value_counts().head()
plt.figure(figsize=(5,8))
plt.pie(days_counts, labels=days_counts.index, autopct='%1.f%%', startangle=90, colors=sns.color_palette('pastel'))
plt.title('Distribution of Number of visiting cities for Trips')
plt.show()

# %% [markdown]
# - OBSERVATION:
# - Most of the trips are for 1 and 2 days.
# - we have less long trips.

# %%
sns.scatterplot(df,x="no.of_visiting_cities",y="trip_price")
# Out:
# <Axes: xlabel='no.of_visiting_cities', ylabel='trip_price'>

# %% [markdown]
# - OBSERVATION:
# - As the trip price increases number of visiting places also increases

# %%
correlation_matrix = df[['days', 'no.of_visiting_cities']].corr()
plt.figure(figsize=(6, 4))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap: Number of Days and Number of Visiting Cities')
plt.show()

# %%
long_vacation=df[df.days>10]

# %%
long_vacation.groupby('city_name')[['actual_price','trip_price']].mean()
# Out:
#                     actual_price     trip_price
# city_name
# Athens             113932.000000  103599.500000
# Auckland           128165.750000  120431.750000
# Gold Coast          27156.000000   25798.000000
# Hanoi               61111.000000   55000.000000
# Haridwar            20769.000000   18900.000000
# Ho Chi Minh City    74157.000000   66000.000000
# Istanbul           109538.000000   99680.000000
# Jaipur              14285.000000   12999.000000
# Kuta                37362.000000   33999.000000
# London              25274.000000   22999.000000
# Mussoorie           40588.000000   36529.000000
# New York           274725.000000  250000.000000
# Rome               120989.666667  110624.666667
# Sydney              39560.000000   36000.000000
# Vienna               8847.000000    8051.000000

# %%
plt.figure(figsize=(6, 6))
melted_data = long_vacation.melt(id_vars='city_name', value_vars=['actual_price', 'trip_price'], var_name='Price Type', value_name='Price')
sns.barplot(x='city_name', y='Price', hue='Price Type', data=melted_data, palette='Set1')
plt.title('Average Actual Price and Trip Price by City')
plt.xlabel('City Name')
plt.ylabel('Average Price')
plt.xticks(rotation=90) 
plt.show()

# %% [markdown]
# - OBSERVATION:
# - These are the budget difference between cities with longer duration in the vacation
# - New York have the high budget and there are cities with low budget and long duration

# %%
low_budget=df[df.trip_price<=15000]
low_budget
# Out:
#                                           package_name  actual_price  \
# 0    Bestselling Rishikesh Mussoorie Tour Package F...         12545
# 5      Mesmerising Manali Trip Package From Chandigarh         10440
# 6    Most Affordable 1 Night 2 Days Uttarakhand Tou...          3360
# 8    Top Family Holiday Packages in Goa for an Idea...         15217
# 25   Udaipur: More Than The Just âThe City Of Lak...          7539
# ..                                                 ...           ...
# 452    An Enthralling Jodhpur Sightseeing Tour Package         10989
# 460                Delightful Mount Abu Family Package          5494
# 462                    Bewitching Pelling Tour Package         15995
# 464  Exciting Kanyakumari-Kovalam Family Tour Package          13068
# 467                     Adventurous Assam Tour Package         15730
#
#      trip_price                 visiting_places          hotel_ratings  \
# ...

# %%
medium_budget=df[(df.trip_price>15000) & (df.trip_price<45000)]
medium_budget
# Out:
#                                           package_name  actual_price  \
# 1    Best Hong Kong Macau Tour Packages For An Impe...         43157
# 2                Coorg Package For 2 Nights And 3 Days         17802
# 3    Refreshing Maldives Family Tour Packages From ...         80000
# 4    Best 4N 5D Andaman Sightseeing Tour Package Fo...         36484
# 7    Splendid Dubai Abu Dhabi Tour Packages For An ...         26595
# ..                                                 ...           ...
# 461                        Kerala is a Land of Wonders         22988
# 463                   Delightful Cambodia Tour Package         28913
# 465                      Elegant Srinagar Tour Package         20225
# 466          Sizzling Pattaya Sightseeing Tour Package         37362
# 470                 Gleeful Rann Of Kutch Tour Package         22087
#
#      trip_price                                    visiting_places  \
# 1         39999                         Hong Kong (4D),Macau (3D),
# ...

# %%
high_budget=df[(df.trip_price>45000) & (df.trip_price<250000)]
high_budget
# Out:
#                                           package_name  actual_price  \
# 11   Top Greece Tour Packages For An Enthralling Ex...         74974
# 20   Best Selling Paris Tour Packages For An Exquis...         93333
# 22   Explore The Lion City With Best Singapore Sigh...         53846
# 26                Classic Holiday Package To Australia         91455
# 30                   Colorful Rajasthan Family Package         76404
# ..                                                 ...           ...
# 454                 Exhilarating Malaysia Tour Package         63736
# 457                Breathtaking Ladakh Family Package          69999
# 458  Incredible Italy, Switzerland & Paris Family P...        139186
# 468  New Zealand Queenstown, Rotorua & Franz Josef ...        150081
# 469   Ecstatic Cambodia Vietnam Family Holiday Package         61111
#
#      trip_price                                    visiting_places  \
# 11        68726           Athens (3D),Santorini (2D),Mykonos (2D),
# ...

# %%
dff=low_budget.groupby('city_name')[['actual_price','trip_price']].mean().sort_values(by='trip_price',ascending=True).sample(10)

# %%
sns.barplot(x=dff['actual_price'], y=dff.index, color='lightblue', label='Actual Price')
sns.barplot(x=dff['trip_price'], y=dff.index, color='pink', label='Trip Price')
plt.title('Average Actual Price and Trip Price in Low Budget')
plt.xlabel('Average Price')
plt.ylabel('City Name')
plt.legend()
plt.show()

# %% [markdown]
# - OBSERVATION:
# - Here are the top 10 cities in low budget

# %%
dff1=medium_budget.groupby('city_name')[['actual_price','trip_price']].mean().sort_values(by='trip_price',ascending=True).sample(10)

# %%
plt.plot(dff1.index, dff1['actual_price'], marker='o', label='Actual Price', color='green')
plt.plot(dff1.index, dff1['trip_price'], marker='o', label='Trip Price', color='red')
plt.title('Average Actual Price and Trip Price by City in Medium Budget')
plt.ylabel('Average Price')
plt.xlabel('City Name')
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.show()

# %%
dff2=high_budget.groupby('city_name')[['actual_price','trip_price']].mean().sort_values(by='trip_price',ascending=True).sample(10)

# %%
# Plot the stacked bar chart
dff2.plot(kind='bar', stacked=True, figsize=(6,6), color=['lightblue', 'pink'])

# Add labels and title
plt.title('Actual Price and Trip Price by City in High Budget')
plt.ylabel('Average Price')
plt.xlabel('City Name')
plt.xticks(rotation=45)

# Display the plot
plt.tight_layout()
plt.show()

# %%
high_budget.groupby('city_name')[['actual_price','trip_price']].mean().sort_values(by='trip_price',ascending=True).sample(10)
# Out:
#                 actual_price  trip_price
# city_name
# Maldives       110996.500000    102250.0
# Goa             90785.000000     84875.0
# Gangtok         64127.000000     58573.6
# Kuala Lumpur    63736.000000     58000.0
# Hong Kong       49947.666667     46166.0
# Mount Abu       89344.500000     79154.5
# Christchurch    95415.000000     85604.5
# Jodhpur        117109.000000    114000.0
# Coorg           53846.000000     49000.0
# Praslin         73667.000000     67417.0

# %%
# Plot the stacked bar chart
high_budget.groupby('city_name')[['actual_price','trip_price']].mean().sort_values(by='trip_price',ascending=True).sample(10).plot(kind='bar', stacked=True, figsize=(10,6), color=['lightblue', 'pink'])

# Add labels and title
plt.title('Stacked Bar Chart: Actual Price and Trip Price by City')
plt.ylabel('Average Price')
plt.xlabel('City Name')
plt.xticks(rotation=45)

# Display the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# # conclusion
# - Discount and price factors are affecting the number of vacation days and visiting cities.
# - There is a strong correlation between number of days and visiting cities.
# - Price varies according to the number of days of trip.
# - Classified cities according to the budget where every parameter changes when price is varying.
# - Most of the trips last for 5 to 6 days.
# - In every trip mostly tourists visit 1 city.
# - There are highest discounts for some trips.
# - Hotel ratings are also affecting the price.
# - For some trips cost is too high and some are low cost can be travelled according to the budget.
